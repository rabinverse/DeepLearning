# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/customer_churn_dataset-testing-master.csv")

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
df=df.drop(columns={"Gender","Subscription Type","Contract Length",})

# %%
df.sample()
# Out:
#       CustomerID  Age  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 7937        7938   29       5                2              7             17
#
#       Total Spend  Last Interaction  Churn
# 7937          375                13      1

# %%
x=df.drop(columns="Churn")
y=df["Churn"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_df = df.select_dtypes(include=[np.number])

plt.figure(figsize=(10,6))
sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((51499, 8), (12875, 8), (51499,), (12875,))

# %%
xtrain_trans=scaler.fit_transform(xtrain)
xtest_trans=scaler.transform(xtest)

# %%
xtrain_trans[:10]
# Out:
# array([[-1.00468516,  1.00748863,  0.58691645, -0.46172589, -1.73383506,
#         -0.80597895,  0.96828798, -0.05782578],
#        [-0.64705319,  0.86400944,  1.63912853, -1.14230525, -0.77004023,
#         -0.9188338 ,  0.26657637,  0.98455628],
#        [ 0.87452295, -0.78600122, -1.16677034, -1.48259492,  1.15754942,
#         -1.14454349, -1.22120563,  1.67947765],
#        [ 0.53646663, -0.64252203, -0.58220808,  0.21885346, -0.12751035,
#          0.88684376,  0.41228698,  0.52127537],
#        [ 1.23527412, -0.21208447, -0.23147072,  1.69344206, -1.09130517,
#          0.88684376,  1.69684102,  0.75291582],
#        [ 0.8295635 , -1.28817837, -0.93294544, -0.68858568, -1.41257012,
#          1.451118  ,  0.5886735 ,  0.75291582],
#        [ 1.65308506,  0.07487391,  1.52221607, -0.91544546, -1.73383506,
#          0.66113406, -1.02564666, -0.75274715],
#        [ 0.09520793,  0.00313431,  1.05456626,  0.55914314, -0.77004023,
#         -0.46741441,  1.6699996 , -1.33184829],
#        [-0.60709521,  0.86400944, -0.99140166,  1.1262926 , -0.44877529,
#         -0.46741441,  1.54729593,  0.6370956 ],
#        [-1.45761395, -1.71861593, -0.17301449, -0.91544546,  0.51501954,
#         -1.70881773, -0.36994892, -0.52110669]])

# %%
import tensorflow
from tensorflow.keras import Sequential, layers
from keras.layers import Dense,BatchNormalization

# %%
model=Sequential()
model.add(Dense(8,activation="relu",input_dim=8))
model.add(Dense(4,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 113 (452.00 B)
#  Trainable params: 113 (452.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[-0.4771586 ,  0.07416034,  0.45816118, -0.06108564, -0.3442208 ,
#           0.49990922, -0.20881483,  0.5438586 ],
#         [-0.29540378,  0.33073992,  0.5762463 , -0.45261455, -0.2488921 ,
#          -0.31184947,  0.15219796, -0.21364161],
#         [-0.09946477,  0.30448866,  0.26160306,  0.23353642, -0.12149647,
#           0.06661922,  0.31672502,  0.28788543],
#         [-0.344709  , -0.18159324,  0.19785833,  0.08068568,  0.3668908 ,
#           0.3740155 ,  0.30926687, -0.23573157],
#         [-0.5400155 ,  0.42330796,  0.0418433 , -0.03277856, -0.1639629 ,
#          -0.32180744,  0.4020031 , -0.20243296],
#         [-0.44703555, -0.40485734, -0.44679582, -0.5625413 ,  0.03773016,
#           0.5681136 ,  0.4156471 ,  0.09302318],
#         [ 0.43102258,  0.13978177,  0.4183753 , -0.24149305, -0.0089795 ,
#          -0.15024346, -0.5760016 , -0.21398705],
#         [ 0.13181436, -0.06952041,  0.03641397,  0.13547778, -0.43147683,
#          -0.15202102,  0.07678074, -0.1773043 ]], dtype=float32),
#  array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32),
#  array([[-0.6182533 , -0.28953874,  0.2745191 ,  0.36135024],
#         [ 0.48182946,  0.3623157 , -0.10906607, -0.59489787],
#         [-0.42531058,  0.01093608, -0.24268728, -0.41476476],
#         [-0.66945344,  0.21426177,  0.3705507 ,  0.3454954 ],
#         [ 0.30225044,  0.4555835 ,  0.20423067,  0.15941   ],
#         [-0.6291002 ,  0.40452307,  0.02330047,  0.35724837],
#         [ 0.46080798, -0.03701758, -0.5102756 , -0.62666935],
#         [ 0.32514924, -0.44864324, -0.59186226,  0.49057156]],
#        dtype=float32),
#  array([0., 0., 0., 0.], dtype=float32),
#  array([[-0.51974374],
#         [-0.77055246],
#         [ 0.2654562 ],
#         [ 0.22480285]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
history=model.fit(xtrain_trans,ytrain,validation_split=0.2,epochs=50)
# Out:
# Epoch 1/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7421 - loss: 0.4938 - val_accuracy: 0.8800 - val_loss: 0.2772
# Epoch 2/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8782 - loss: 0.2721 - val_accuracy: 0.8951 - val_loss: 0.2291
# Epoch 3/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8950 - loss: 0.2344 - val_accuracy: 0.9039 - val_loss: 0.2109
# Epoch 4/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9008 - loss: 0.2167 - val_accuracy: 0.9109 - val_loss: 0.1991
# Epoch 5/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9068 - loss: 0.2029 - val_accuracy: 0.9141 - val_loss: 0.1890
# Epoch 6/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9105 - loss: 0.1946 - val_accuracy: 0.9169 - val_loss: 0.1824
# Epoch 7/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9137 - loss: 0.1873 - val_accuracy: 0.9205 - val_loss: 0.1768
# Epoch 8/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9161 - loss: 0.1807 - val_accuracy: 0.9234 - val_loss: 0.1725
# Epoch 9/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9193 - loss: 0.1759 - val_accuracy: 0.9245 - val_loss: 0.1703
# Epoch 10/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9209 - loss: 0.1707 - val_accuracy: 0.9247 - val_loss: 0.1679
# Epoch 11/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9205 - loss: 0.1711 - val_accuracy: 0.9265 - val_loss: 0.1653
# Epoch 12/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9203 - loss: 0.1695 - val_accuracy: 0.9275 - val_loss: 0.1636
# Epoch 13/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9244 - loss: 0.1646 - val_accuracy: 0.9249 - val_loss: 0.1636
# Epoch 14/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9230 - loss: 0.1646 - val_accuracy: 0.9276 - val_loss: 0.1604
# Epoch 15/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9238 - loss: 0.1629 - val_accuracy: 0.9267 - val_loss: 0.1608
# Epoch 16/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9230 - loss: 0.1623 - val_accuracy: 0.9280 - val_loss: 0.1597
# Epoch 17/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9236 - loss: 0.1615 - val_accuracy: 0.9305 - val_loss: 0.1583
# Epoch 18/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9246 - loss: 0.1583 - val_accuracy: 0.9274 - val_loss: 0.1586
# Epoch 19/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9233 - loss: 0.1596 - val_accuracy: 0.9304 - val_loss: 0.1579
# Epoch 20/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9236 - loss: 0.1619 - val_accuracy: 0.9307 - val_loss: 0.1574
# Epoch 21/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9263 - loss: 0.1587 - val_accuracy: 0.9298 - val_loss: 0.1561
# Epoch 22/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9222 - loss: 0.1649 - val_accuracy: 0.9297 - val_loss: 0.1559
# Epoch 23/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9257 - loss: 0.1603 - val_accuracy: 0.9295 - val_loss: 0.1572
# Epoch 24/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9257 - loss: 0.1573 - val_accuracy: 0.9317 - val_loss: 0.1554
# Epoch 25/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9260 - loss: 0.1593 - val_accuracy: 0.9318 - val_loss: 0.1547
# Epoch 26/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9242 - loss: 0.1591 - val_accuracy: 0.9253 - val_loss: 0.1577
# Epoch 27/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9261 - loss: 0.1582 - val_accuracy: 0.9326 - val_loss: 0.1541
# Epoch 28/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9257 - loss: 0.1586 - val_accuracy: 0.9323 - val_loss: 0.1550
# Epoch 29/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9265 - loss: 0.1571 - val_accuracy: 0.9316 - val_loss: 0.1534
# Epoch 30/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9288 - loss: 0.1546 - val_accuracy: 0.9324 - val_loss: 0.1547
# Epoch 31/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9297 - loss: 0.1554 - val_accuracy: 0.9327 - val_loss: 0.1537
# Epoch 32/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9285 - loss: 0.1549 - val_accuracy: 0.9334 - val_loss: 0.1541
# Epoch 33/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9272 - loss: 0.1572 - val_accuracy: 0.9297 - val_loss: 0.1543
# Epoch 34/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9277 - loss: 0.1585 - val_accuracy: 0.9326 - val_loss: 0.1530
# Epoch 35/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9285 - loss: 0.1541 - val_accuracy: 0.9266 - val_loss: 0.1589
# Epoch 36/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9283 - loss: 0.1556 - val_accuracy: 0.9305 - val_loss: 0.1541
# Epoch 37/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9285 - loss: 0.1537 - val_accuracy: 0.9317 - val_loss: 0.1523
# Epoch 38/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9286 - loss: 0.1543 - val_accuracy: 0.9319 - val_loss: 0.1532
# Epoch 39/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9267 - loss: 0.1599 - val_accuracy: 0.9338 - val_loss: 0.1522
# Epoch 40/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9283 - loss: 0.1551 - val_accuracy: 0.9250 - val_loss: 0.1567
# Epoch 41/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9246 - loss: 0.1604 - val_accuracy: 0.9323 - val_loss: 0.1534
# Epoch 42/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9298 - loss: 0.1575 - val_accuracy: 0.9298 - val_loss: 0.1534
# Epoch 43/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9294 - loss: 0.1542 - val_accuracy: 0.9323 - val_loss: 0.1518
# Epoch 44/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9315 - loss: 0.1510 - val_accuracy: 0.9332 - val_loss: 0.1517
# Epoch 45/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9261 - loss: 0.1563 - val_accuracy: 0.9317 - val_loss: 0.1518
# Epoch 46/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9278 - loss: 0.1567 - val_accuracy: 0.9323 - val_loss: 0.1507
# Epoch 47/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9296 - loss: 0.1539 - val_accuracy: 0.9317 - val_loss: 0.1510
# Epoch 48/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9305 - loss: 0.1501 - val_accuracy: 0.9294 - val_loss: 0.1534
# Epoch 49/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9300 - loss: 0.1509 - val_accuracy: 0.9305 - val_loss: 0.1510
# Epoch 50/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9308 - loss: 0.1518 - val_accuracy: 0.9318 - val_loss: 0.1506

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])

# %% [markdown]
# # batch normalized

# %%
model2=Sequential()
model2.add(Dense(8,activation="relu",input_dim=8))
model2.add(BatchNormalization())
model2.add(Dense(4,activation="relu"))
model2.add(BatchNormalization())
model2.add(Dense(1,activation="sigmoid"))
model2.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8)              │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 4)              │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 161 (644.00 B)
#  Trainable params: 137 (548.00 B)
#  Non-trainable params: 24 (96.00 B)

# %%
model2.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
history2=model2.fit(xtrain_trans,ytrain,validation_split=0.2,epochs=50)
# Out:
# Epoch 1/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9279 - loss: 0.1633 - val_accuracy: 0.9413 - val_loss: 0.1364
# Epoch 2/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.9258 - loss: 0.1664 - val_accuracy: 0.9403 - val_loss: 0.1389
# Epoch 3/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9248 - loss: 0.1657 - val_accuracy: 0.9405 - val_loss: 0.1361
# Epoch 4/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9251 - loss: 0.1673 - val_accuracy: 0.9406 - val_loss: 0.1369
# Epoch 5/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9256 - loss: 0.1625 - val_accuracy: 0.9391 - val_loss: 0.1386
# Epoch 6/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9250 - loss: 0.1631 - val_accuracy: 0.9380 - val_loss: 0.1440
# Epoch 7/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9273 - loss: 0.1615 - val_accuracy: 0.9401 - val_loss: 0.1383
# Epoch 8/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9268 - loss: 0.1614 - val_accuracy: 0.9404 - val_loss: 0.1356
# Epoch 9/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9266 - loss: 0.1641 - val_accuracy: 0.9384 - val_loss: 0.1401
# Epoch 10/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9234 - loss: 0.1653 - val_accuracy: 0.9377 - val_loss: 0.1408
# Epoch 11/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9239 - loss: 0.1645 - val_accuracy: 0.9380 - val_loss: 0.1389
# Epoch 12/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9265 - loss: 0.1618 - val_accuracy: 0.9383 - val_loss: 0.1374
# Epoch 13/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9252 - loss: 0.1625 - val_accuracy: 0.9383 - val_loss: 0.1370
# Epoch 14/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9248 - loss: 0.1619 - val_accuracy: 0.9393 - val_loss: 0.1394
# Epoch 15/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9235 - loss: 0.1649 - val_accuracy: 0.9411 - val_loss: 0.1368
# Epoch 16/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9274 - loss: 0.1600 - val_accuracy: 0.9393 - val_loss: 0.1353
# Epoch 17/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9262 - loss: 0.1616 - val_accuracy: 0.9383 - val_loss: 0.1401
# Epoch 18/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9250 - loss: 0.1641 - val_accuracy: 0.9392 - val_loss: 0.1363
# Epoch 19/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9247 - loss: 0.1657 - val_accuracy: 0.9397 - val_loss: 0.1443
# Epoch 20/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9262 - loss: 0.1615 - val_accuracy: 0.9413 - val_loss: 0.1393
# Epoch 21/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9287 - loss: 0.1584 - val_accuracy: 0.9390 - val_loss: 0.1383
# Epoch 22/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9262 - loss: 0.1614 - val_accuracy: 0.9407 - val_loss: 0.1375
# Epoch 23/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9273 - loss: 0.1607 - val_accuracy: 0.9394 - val_loss: 0.1382
# Epoch 24/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9256 - loss: 0.1608 - val_accuracy: 0.9385 - val_loss: 0.1378
# Epoch 25/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9270 - loss: 0.1580 - val_accuracy: 0.9396 - val_loss: 0.1347
# Epoch 26/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9279 - loss: 0.1615 - val_accuracy: 0.9400 - val_loss: 0.1364
# Epoch 27/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9269 - loss: 0.1589 - val_accuracy: 0.9415 - val_loss: 0.1376
# Epoch 28/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9271 - loss: 0.1626 - val_accuracy: 0.9425 - val_loss: 0.1327
# Epoch 29/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9283 - loss: 0.1617 - val_accuracy: 0.9425 - val_loss: 0.1363
# Epoch 30/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9293 - loss: 0.1573 - val_accuracy: 0.9421 - val_loss: 0.1348
# Epoch 31/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9290 - loss: 0.1575 - val_accuracy: 0.9425 - val_loss: 0.1340
# Epoch 32/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9273 - loss: 0.1594 - val_accuracy: 0.9400 - val_loss: 0.1367
# Epoch 33/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9279 - loss: 0.1580 - val_accuracy: 0.9403 - val_loss: 0.1385
# Epoch 34/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9304 - loss: 0.1573 - val_accuracy: 0.9443 - val_loss: 0.1364
# Epoch 35/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9323 - loss: 0.1529 - val_accuracy: 0.9400 - val_loss: 0.1377
# Epoch 36/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9278 - loss: 0.1569 - val_accuracy: 0.9428 - val_loss: 0.1325
# Epoch 37/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9290 - loss: 0.1592 - val_accuracy: 0.9435 - val_loss: 0.1328
# Epoch 38/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9317 - loss: 0.1531 - val_accuracy: 0.9431 - val_loss: 0.1306
# Epoch 39/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9265 - loss: 0.1619 - val_accuracy: 0.9417 - val_loss: 0.1336
# Epoch 40/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9314 - loss: 0.1564 - val_accuracy: 0.9436 - val_loss: 0.1343
# Epoch 41/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9294 - loss: 0.1558 - val_accuracy: 0.9429 - val_loss: 0.1329
# Epoch 42/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9329 - loss: 0.1531 - val_accuracy: 0.9397 - val_loss: 0.1355
# Epoch 43/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9266 - loss: 0.1585 - val_accuracy: 0.9435 - val_loss: 0.1341
# Epoch 44/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9315 - loss: 0.1557 - val_accuracy: 0.9426 - val_loss: 0.1334
# Epoch 45/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9312 - loss: 0.1549 - val_accuracy: 0.9429 - val_loss: 0.1357
# Epoch 46/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9306 - loss: 0.1566 - val_accuracy: 0.9428 - val_loss: 0.1325
# Epoch 47/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9323 - loss: 0.1552 - val_accuracy: 0.9425 - val_loss: 0.1357
# Epoch 48/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9328 - loss: 0.1536 - val_accuracy: 0.9415 - val_loss: 0.1366
# Epoch 49/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9313 - loss: 0.1545 - val_accuracy: 0.9420 - val_loss: 0.1352
# Epoch 50/50
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9316 - loss: 0.1552 - val_accuracy: 0.9441 - val_loss: 0.1327

# %%
plt.plot(history2.history["loss"])
plt.plot(history2.history["val_loss"])

# %%
plt.plot(history2.history["accuracy"])
plt.plot(history2.history["val_accuracy"])

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
